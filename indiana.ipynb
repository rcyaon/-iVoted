# %%
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt # data visualization
import seaborn as sns # data visualization
import plotly.graph_objs as go
import plotly.express as px

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/2018-indiana-election-data-mit-election-lab/Indiana (2).csv

# %%
df_office = pd.read_csv("/kaggle/input/2018-indiana-election-data-mit-election-lab/Indiana (2).csv")

# %%
df_office
# Out:
#                     Election                  Jurisdiction_Name  \
# 0      2018 General Election                          Statewide
# 1      2018 General Election                          Statewide
# 2      2018 General Election                          Statewide
# 3      2018 General Election                          Statewide
# 4      2018 General Election                          Statewide
# ...                      ...                                ...
# 10560  2018 General Election                             Warren
# 10561  2018 General Election                         Washington
# 10562  2018 General Election                              Wayne
# 10563  2018 General Election                              Wayne
# 10564  2018 General Election  Lake Of The Woods Sewage District
#
#       Reporting_County_Name DataEntry_Jurisdiction_Name DataEntry_Level_Name  \
# 0                     Adams                       Adams             Locality
# ...

# %%
df_office.shape
# Out:
# (10565, 13)

# %%
df_office.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10565 entries, 0 to 10564
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Election                     10565 non-null  object
#  1   Jurisdiction_Name            10565 non-null  object
#  2   Reporting_County_Name        10565 non-null  object
#  3   DataEntry_Jurisdiction_Name  10565 non-null  object
#  4   DataEntry_Level_Name         10565 non-null  object
#  5   Office                       10565 non-null  object
#  6   Office_Category              10565 non-null  object
#  7   Ballot_Order                 10565 non-null  int64
#  8   Name_on_Ballot               10565 non-null  object
#  9   Political_Party              10565 non-null  object
#  10  Winner                       10565 non-null  object
#  11  Number_of_Office_Seats       10565 non-null  int64
#  12  Total_Votes                  10565 non-null  int64
# ...

# %%
df_office = df_office.astype (
    {
        "Office_Category": "category",
        "Name_on_Ballot": "category",
        "Political_Party": "category",
        "Winner": "category",
        "Total_Votes": "category",
    }
)
df_office.drop(columns=["Election", "Jurisdiction_Name", "Reporting_County_Name", "DataEntry_Jurisdiction_Name", "Ballot_Order", "Number_of_Office_Seats", "Office", "DataEntry_Level_Name"], inplace=True)

# %%
df_office.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10565 entries, 0 to 10564
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Office_Category  10565 non-null  category
#  1   Name_on_Ballot   10565 non-null  category
#  2   Political_Party  10565 non-null  category
#  3   Winner           10565 non-null  category
#  4   Total_Votes      10565 non-null  category
# dtypes: category(5)
# memory usage: 553.4 KB

# %%
df_office.head()
# Out:
#   Office_Category              Name_on_Ballot Political_Party Winner  \
# 0      US Senator   Christopher Fischer (W/I)     Independent     No
# 1      US Senator  James L. Johnson Jr. (W/I)           Other     No
# 2      US Senator                Joe Donnelly      Democratic     No
# 3      US Senator             Lucy M. Brenton     Libertarian     No
# 4      US Senator                  Mike Braun      Republican     No
#
#   Total_Votes
# 0           0
# 1           0
# 2        3145
# 3         489
# 4        7510

# %%
votes = list(df_office.Total_Votes.unique())

# %%
candidates = list(df_office.Name_on_Ballot.unique())

# %%
# resizes the figure
plt.figure(figsize=(12,8))

# code that creates the plot
plt.bar(df_office['Total_Votes'], df_office['Name_on_Ballot'])

# rotates the genre names on the x axis
plt.xticks(rotation=90)

# creates a title at the top of the chart
plt.title('2018 Indiana Election Data', fontsize=20);
# Out:
# Error in callback <function flush_figures at 0x7ac4069aa560> (for post_execute):
# KeyboardInterrupt
